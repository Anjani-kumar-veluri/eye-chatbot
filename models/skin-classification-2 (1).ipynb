# %%
import os
import shutil
import random

# %%
# Source folder (your images)
source_folder = '/home/bhcp0089/Desktop/AiMedicalChatbot_updated/coco/non_eye_train'

# Destination folders
train_folder = "/home/bhcp0089/Desktop/AiMedicalChatbot_updated/coco/non_eye_train/train"
test_folder  = "/home/bhcp0089/Desktop/AiMedicalChatbot_updated/coco/non_eye_train/test"

# Create folders
os.makedirs(train_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)

# Get all images
images = [f for f in os.listdir(source_folder) 
          if f.lower().endswith(('.jpg','.jpeg','.png','.bmp'))]

# Shuffle randomly
random.shuffle(images)

# Split 80% - 20%
split_index = int(0.8 * len(images))
train_images = images[:split_index]
test_images = images[split_index:]

# Copy to train
for img in train_images:
    shutil.copy(os.path.join(source_folder, img),
                os.path.join(train_folder, img))

# Copy to test
for img in test_images:
    shutil.copy(os.path.join(source_folder, img),
                os.path.join(test_folder, img))

print(f"Train: {len(train_images)} images")
print(f"Test: {len(test_images)} images")
# Out:
# Train: 7225 images
# Test: 1807 images

# %%
# Source directory (update this to your actual dataset location)
coco_dir = '/home/bhcp0089/Desktop/AiMedicalChatbot_updated/coco/non_eye_train/train'  

# Base directory (your project folder)
base_dir = '/home/bhcp0089/Desktop/AiMedicalChatbot_updated/data'

# %%
# Create dataset folders
# eye_dir = os.path.join(base_dir, 'eye_train')
non_eye_dir = os.path.join(base_dir, 'non_eye_train')

# Create folders
# os.makedirs(eye_dir, exist_ok=True)
os.makedirs(non_eye_dir, exist_ok=True)

# Function to copy images
def copy_images(src_dir, dest_dir, num_images):
    all_images = [f for f in os.listdir(src_dir) if f.endswith(('.jpg', '.png', '.jpeg'))]
    selected_images = random.sample(all_images, min(len(all_images), num_images))
    
    for img in selected_images:
        shutil.copy(os.path.join(src_dir, img), os.path.join(dest_dir, img))

# Copy non-eye images
copy_images(coco_dir, non_eye_dir, 9000)

print("✅ Dataset successfully created!")

print("✅ Dataset successfully created with 'eye' and 'non_eye' categories!")
# Out:
# ✅ Dataset successfully created!
# ✅ Dataset successfully created with 'eye' and 'non_eye' categories!

# %%
import os
import shutil

# 🔹 Source (main folder with subfolders)
source_root = "/home/bhcp0089/Desktop/AiMedicalChatbot_updated/archive/preprocessed"

# 🔹 Destination (new folder with all images)
destination_folder = "/home/bhcp0089/Desktop/AiMedicalChatbot_updated/eye/all_images"

# Create destination folder
os.makedirs(destination_folder, exist_ok=True)

# Loop through all subfolders and files
for root, _, files in os.walk(source_root):
    for file in files:
        if file.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp')):
            source_path = os.path.join(root, file)
            dest_path = os.path.join(destination_folder, file)

            # 🔸 Avoid duplicate file overwrite
            counter = 1
            while os.path.exists(dest_path):
                name, ext = os.path.splitext(file)
                dest_path = os.path.join(destination_folder, f"{name}_{counter}{ext}")
                counter += 1

            shutil.copy2(source_path, dest_path)

print("✅ All images merged into one folder!")
# Out:
# ✅ All images merged into one folder!

# %%
# Source folder (your images)
source_folder = '/home/bhcp0089/Desktop/AiMedicalChatbot_updated/eye/all_images'

# Destination folders
train_folder = "/home/bhcp0089/Desktop/AiMedicalChatbot_updated/eye/all_images/train"
test_folder  = "/home/bhcp0089/Desktop/AiMedicalChatbot_updated/eye/all_images/test"

# Create folders
os.makedirs(train_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)

# Get all images
images = [f for f in os.listdir(source_folder) 
          if f.lower().endswith(('.jpg','.jpeg','.png','.bmp'))]

# Shuffle randomly
random.shuffle(images)

# Split 80% - 20%
split_index = int(0.8 * len(images))
train_images = images[:split_index]
test_images = images[split_index:]

# Copy to train
for img in train_images:
    shutil.copy(os.path.join(source_folder, img),
                os.path.join(train_folder, img))

# Copy to test
for img in test_images:
    shutil.copy(os.path.join(source_folder, img),
                os.path.join(test_folder, img))

print(f"Train: {len(train_images)} images")
print(f"Test: {len(test_images)} images")
# Out:
# Train: 8031 images
# Test: 2008 images

# %%
import os
import shutil

source_folder = '/home/bhcp0089/Desktop/AiMedicalChatbot_updated/eye/all_images/train'

destination_folder = '/home/bhcp0089/Desktop/AiMedicalChatbot_updated/data/eye_train'

# Ensure destination folder exists
os.makedirs(destination_folder, exist_ok=True)

# Loop through all the images in the source folder
for filename in os.listdir(source_folder):
    # Construct the full file path
    source_file = os.path.join(source_folder, filename)
    
    # Check if it's a file (image file)
    if os.path.isfile(source_file):
        # Construct destination file path
        destination_file = os.path.join(destination_folder, filename)
        
        # Copy the file from source to destination
        shutil.copy(source_file, destination_file)

print(f"All images from {source_folder} have been copied to {destination_folder}.")
# Out:
# All images from /home/bhcp0089/Desktop/AiMedicalChatbot_updated/eye/all_images/train have been copied to /home/bhcp0089/Desktop/AiMedicalChatbot_updated/data/eye_train.

# %%
import os
import shutil
import random

# ✅ Define source and destination folders
source_folder = "/home/bhcp0089/Desktop/AiMedicalChatbot_updated/coco/non_eye_train/test"  # Change this to your dataset location
destination_folder = "/home/bhcp0089/Desktop/AiMedicalChatbot_updated/data/non_eye_t" # Change this if needed
num_images_to_copy = 5000  # ✅ Number of images to copy

# ✅ Create destination folder if it doesn't exist
os.makedirs(destination_folder, exist_ok=True)

# ✅ Collect all image file paths
image_paths = []
for root, _, files in os.walk(source_folder):
    for file in files:
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):  # ✅ Check for image formats
            image_paths.append(os.path.join(root, file))

# ✅ Ensure we don't exceed available images
num_images_to_copy = min(num_images_to_copy, len(image_paths))
print(f"🔹 Found {len(image_paths)} images. Copying {num_images_to_copy} randomly.")

# ✅ Shuffle and select 1,300 images randomly
random.shuffle(image_paths)
selected_images = image_paths[:num_images_to_copy]

# ✅ Copy the selected images
for img_path in selected_images:
    file_name = os.path.basename(img_path)
    dest_path = os.path.join(destination_folder, file_name)

    # ✅ Avoid duplicate filenames
    counter = 1
    while os.path.exists(dest_path):
        name, ext = os.path.splitext(file_name)
        dest_path = os.path.join(destination_folder, f"{name}_{counter}{ext}")
        counter += 1

    shutil.copy2(img_path, dest_path)  # ✅ Copy image

print(f"✅ {num_images_to_copy} images copied to {destination_folder}")
# Out:
# 🔹 Found 1807 images. Copying 1807 randomly.
# ✅ 1807 images copied to /home/bhcp0089/Desktop/AiMedicalChatbot_updated/data/non_eye_t

# %%
import os
import random
import shutil

def move_half_images(source_folder, destination_folder):
    # Create destination folder if it doesn't exist
    os.makedirs(destination_folder, exist_ok=True)

    # Get a list of all image files in the source folder
    image_files = [f for f in os.listdir(source_folder) if f.lower().endswith(('png', 'jpg', 'jpeg', 'bmp', 'tiff'))]

    # Shuffle and select half of the images
    random.shuffle(image_files)
    num_to_move = len(image_files) // 6
    images_to_move = image_files[:num_to_move]

    # Move selected images to the destination folder
    for img in images_to_move:
        src_path = os.path.join(source_folder, img)
        dest_path = os.path.join(destination_folder, img)
        shutil.move(src_path, dest_path)

    print(f"Moved {num_to_move} images from {source_folder} to {destination_folder}")

# Example usage
source_folder = "/home/bhcp0089/Desktop/AiMedicalChatbot_updated/data/non_eye_train"
destination_folder = "/home/bhcp0089/Desktop/AiMedicalChatbot_updated/data/non_eye_test"
move_half_images(source_folder, destination_folder)
# Out:
# Moved 3336 images from /home/bhcp0089/Desktop/AiMedicalChatbot_updated/data/non_eye_train to /home/bhcp0089/Desktop/AiMedicalChatbot_updated/data/non_eye_test

# %%
import os
import shutil
import random

# # Define source directories
# ham10000_dir = '/kaggle/input/ham1000-segmentation-and-classification/images'
# coco_dir = '/kaggle/input/coco-2017-dataset/coco2017/test2017' # Update if necessary

# # Define new dataset directories
# base_dir = '/kaggle/working/eye_vs_non_eye '
# eye_dir = os.path.join(base_dir, 'eye ')
# non_eye_dir = os.path.join(base_dir, 'non_eye ')

# # Create destination directories
# os.makedirs(eye_dir, exist_ok=True)
# os.makedirs(non_eye_dir, exist_ok=True)

# ✅ Source directories (LOCAL PATHS)
ham10000_dir = "/home/bhcp0089/Desktop/AiMedicalChatbot_updated/eye/all_images/train"
coco_dir = "/home/bhcp0089/Desktop/AiMedicalChatbot_updated/coco/non_eye_train/train"

# ✅ Base directory
base_dir = "/home/bhcp0089/Desktop/AiMedicalChatbot_updated/data/eye_vs_non_eye"

# ✅ Destination folders (NO spaces)
eye_dir = os.path.join(base_dir, "eye")
non_eye_dir = os.path.join(base_dir, "non_eye")

# ✅ Create destination directories
os.makedirs(eye_dir, exist_ok=True)
os.makedirs(non_eye_dir, exist_ok=True)

# Function to copy a fixed number of images
def copy_images(src_dir, dest_dir, num_images):
    all_images = [f for f in os.listdir(src_dir) if f.endswith(('.jpg', '.png', '.jpeg'))]
    selected_images = random.sample(all_images, min(len(all_images), num_images))  # Prevent errors if fewer images exist
    for img in selected_images:
        shutil.copy(os.path.join(src_dir, img), os.path.join(dest_dir, img))

# Copy 5000 eye images from HAM10000 dataset
copy_images(ham10000_dir, eye_dir, 1000)

# Copy 5000 non-eye images from COCO 2017 dataset
copy_images(coco_dir, non_eye_dir, 1000)

print("✅ Dataset successfully created with 'eye' and 'non_eye' categories!")
# Out:
# ✅ Dataset successfully created with 'eye' and 'non_eye' categories!

# %%
# skin_dir = "/kaggle/working/skin_test"
# # non_skin_dir="/kaggle/working/skin_vs_non_skin test/non_skin test"

eye_dir = "/home/bhcp0089/Desktop/AiMedicalChatbot_updated/eye/all_images/test"
# non_eye_dir = "/home/bhcp0089/Desktop/AiMedicalChatbot_updated/data/non_eye_test"

print("Copied eye images:", len(os.listdir(eye_dir)))
# print("Copied non-eye images:", len(os.listdir(non_eye_dir)))
# Out:
# Copied eye images: 2008

# %%
import os
import shutil

# ✅ Define Paths
working_dir = "/home/bhcp0089/Desktop/AiMedicalChatbot_updated/data"
eye_folder = os.path.join(working_dir, "eye_train")
non_eye_folder = os.path.join(working_dir, "non_eye_train")
merged_dataset = os.path.join(working_dir, "train")

# ✅ Create the merged dataset folder
os.makedirs(merged_dataset, exist_ok=True)

# ✅ Move the entire skin and non_skin folders into merged_dataset
shutil.move(eye_folder, os.path.join(merged_dataset, "skin"))
shutil.move(non_eye_folder, os.path.join(merged_dataset, "non_skin"))

print("✅ Both folders moved successfully into 'merged_dataset/'")
# Out:
# ✅ Both folders moved successfully into 'merged_dataset/'

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
import time
import copy
from PIL import Image, ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, random_split

# Define transforms
image_transforms = {
    'train': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
}

# Define the dataset path
dataset_path = "/home/bhcp0089/Desktop/AiMedicalChatbot_updated/data/train"  # Change this to your actual dataset path

def is_valid_file(path):
    try:
        img = Image.open(path)
        img.verify()
        return True
    except:
        return False

# Load the dataset
# full_dataset = ImageFolder(root=dataset_path, transform=image_transforms['train'])

full_dataset = ImageFolder(
    root=dataset_path,
    transform=image_transforms['train'],
    is_valid_file=is_valid_file
)

# Split into training and validation sets (80% train, 20% validation)
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

# Create DataLoader for both
batch_size = 32  # Adjust batch size as needed
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

# Print dataset sizes
print(f"Total samples: {len(full_dataset)}")
print(f"Training samples: {len(train_dataset)}")
print(f"Validation samples: {len(val_dataset)}")
# Out:
# Total samples: 24799
# Training samples: 19839
# Validation samples: 4960

# %%
import torch
import torch.nn as nn
import torchvision.models as models

# Load the EfficientNet model (pretrained on ImageNet)
model = models.efficientnet_b0(pretrained=True)

# Freeze all layers except the last few (set requires_grad=False)
for param in model.parameters():
    param.requires_grad = False

# Unfreeze the last fully connected layer for classification
model.classifier[1].requires_grad = True  # The final fully connected layer

# Modify the classifier for binary classification (2 output classes)
model.classifier[1] = nn.Linear(model.classifier[1].in_features, 2)

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Print the modified model architecture
print(model)
# Out:
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
# ...

# %%
import torch.optim as optim
import torch.nn as nn

# Loss function for binary classification
criterion = nn.CrossEntropyLoss()

# Optimizer, only parameters of the last layer will be updated
optimizer = optim.Adam(model.classifier[1].parameters(), lr=0.001)

# Move criterion to the same device as the model (GPU or CPU)
criterion = criterion.to(device)

# %%
import time

# Training parameters
num_epochs = 15  # You can change this depending on how many epochs you want to train
best_val_loss = float('inf')  # Initialize with a very large value for validation loss
patience = 3  # Number of epochs to wait for improvement before stopping
epochs_without_improvement = 0

# Function to train the model
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, patience, device):
    global best_val_loss  # Use global variable instead of defining it locally
    model.train()  # Set model to training mode
    for epoch in range(num_epochs):
        start_time = time.time()
        running_loss = 0.0
        correct, total = 0, 0

        # Training loop
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)  # Move to GPU

            optimizer.zero_grad()  # Clear gradients
            outputs = model(images)  # Forward pass
            loss = criterion(outputs, labels)  # Compute loss
            loss.backward()  # Backpropagation
            optimizer.step()  # Update weights

            # Track accuracy
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)
            running_loss += loss.item()

        # Validation loop
        model.eval()  # Set model to evaluation mode
        val_loss = 0.0
        val_correct, val_total = 0, 0
        with torch.no_grad():  # No need to calculate gradients during validation
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                _, predicted = torch.max(outputs, 1)
                val_correct += (predicted == labels).sum().item()
                val_total += labels.size(0)

        # Average training loss and accuracy
        epoch_loss = running_loss / len(train_loader)
        epoch_acc = correct / total * 100

        # Average validation loss and accuracy
        val_loss = val_loss / len(val_loader)
        val_acc = val_correct / val_total * 100

        # Print epoch results
        print(f"Epoch [{epoch+1}/{num_epochs}]:")
        print(f"    Train Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_acc:.2f}%")
        print(f"    Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_acc:.2f}%")
        print(f"    Time: {time.time() - start_time:.2f}s")

        # Early stopping: if validation loss doesn't improve, stop training
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            epochs_without_improvement = 0
            # Save the best model
            torch.save(model.state_dict(), 'best_model.pth')
        else:
            epochs_without_improvement += 1

        if epochs_without_improvement >= patience:
            print("Early stopping: Validation loss didn't improve.")
            break

    print("✅ Training Complete!")

# Train the model
train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, patience, device)
# Out:
# Epoch [1/15]:
#     Train Loss: 0.0280, Train Accuracy: 99.45%
#     Validation Loss: 0.0070, Validation Accuracy: 99.96%
#     Time: 2705.58s
# Epoch [2/15]:
#     Train Loss: 0.0032, Train Accuracy: 99.99%
#     Validation Loss: 0.0026, Validation Accuracy: 99.98%
#     Time: 2393.15s
# Epoch [3/15]:
#     Train Loss: 0.0013, Train Accuracy: 99.99%
#     Validation Loss: 0.0017, Validation Accuracy: 99.98%
#     Time: 2220.34s
# Epoch [4/15]:
#     Train Loss: 0.0008, Train Accuracy: 99.99%
#     Validation Loss: 0.0013, Validation Accuracy: 99.98%
#     Time: 2154.07s
# Epoch [5/15]:
#     Train Loss: 0.0005, Train Accuracy: 100.00%
#     Validation Loss: 0.0011, Validation Accuracy: 99.98%
#     Time: 2174.13s
# Epoch [6/15]:
#     Train Loss: 0.0003, Train Accuracy: 100.00%
#     Validation Loss: 0.0010, Validation Accuracy: 99.98%
#     Time: 2355.27s
# Epoch [7/15]:
#     Train Loss: 0.0002, Train Accuracy: 100.00%
#     Validation Loss: 0.0010, Validation Accuracy: 99.98%
# ...

# %%
# Load the best model
model.load_state_dict(torch.load('best_model.pth'))
model.to(device)
model.eval()  # Set to evaluation mode
# Out:
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
# ...

# %%
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import torch
# Define transformation for test set
image_transforms_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load the test dataset
test_dataset = datasets.ImageFolder(root='/home/bhcp0089/Desktop/AiMedicalChatbot_updated/data/eye_vs_non_eye/test', transform=image_transforms_test)

# # Create DataLoader for test dataset
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Load the best model with weights_only=True
model.load_state_dict(torch.load('best_model.pth', weights_only=True))
model.to(device)  # Move model to device (GPU/CPU)
model.eval()  # Set model to evaluation mode

# Evaluate the model
def evaluate_model(model, test_loader, device):
    model.eval()  # Set model to evaluation mode

    correct, total = 0, 0
    with torch.no_grad():  # Disable gradient computation for evaluation
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
        
            # Forward pass
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)  # Get predicted class
        
#             # Calculate accuracy
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    accuracy = 100 * correct / total
    print(f'Accuracy on the test set: {accuracy:.2f}%')

#  Call the evaluation function
evaluate_model(model, test_loader, device)
# Out:
# Accuracy on the test set: 0.01%

# %%
torch.save(model, 'skin_non_skin_model_full.pth')

# %%
# Save the model's state_dict (recommended)
torch.save(model.state_dict(), 'skin_non_skin_model.pth')

# %%
import torch
import torchvision.transforms as transforms
from PIL import Image
import torch.nn as nn
import torchvision.models as models

# Define the same model architecture as used for training
model = models.efficientnet_b0(pretrained=False)  # Use the correct model (change if needed)
num_features = model.classifier[1].in_features  # Get the input size of the classifier layer
model.classifier[1] = nn.Linear(num_features, 2)  # Update output layer for binary classification

# Load the saved state dictionary
model.load_state_dict(torch.load('/home/bhcp0089/Desktop/AiMedicalChatbot_updated/models/skin_non_skin_model.pth', map_location=torch.device('cpu')))
model.eval()  # Set model to evaluation mode

# Define transformation (same as used for training/testing)
image_transforms = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize to match model input size
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Path to a test image
image_path = "/home/bhcp0089/Desktop/AiMedicalChatbot_updated/acne.png"  # Change this to your image path

# Load and preprocess the image
image = Image.open(image_path).convert("RGB")  # Ensure it's in RGB format
image = image_transforms(image).unsqueeze(0)  # Apply transformations and add batch dimension

# Perform inference
with torch.no_grad():
    output = model(image)
    _, predicted_class = torch.max(output, 1)  # Get the class index with highest probability

# efine class labels
class_labels = ["non-eye", "eye"]  # Change based on your dataset
predicted_label = class_labels[predicted_class.item()]

print(f"Predicted Class: {predicted_label}")
# Out:
# Predicted Class: eye
# [W421 11:24:47.605885143 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W421 11:24:47.606565048 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W421 11:24:47.626612587 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W421 11:24:47.626869267 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W421 11:24:47.635291574 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W421 11:24:47.635505556 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W421 11:24:47.645349192 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W421 11:24:47.645544725 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# [W421 11:24:47.649595185 NNPACK.cpp:56] Could not initialize NNPACK! Reason: Unsupported hardware.
# ...
